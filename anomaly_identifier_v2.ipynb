# %% [markdown]
# prima fase di conversione

# %%
# import json
# import ijson

# with open(r"path/to/my/file", "r") as infile, open("public_v2.ndjson", "w") as outfile:
#     for key, value in ijson.kvitems(infile, ''):
#         value["log_id"] = key
#         outfile.write(json.dumps(value) + "\n")

# %%
import duckdb
import pandas as pd

con = duckdb.connect()

df = con.execute("""
    SELECT *
    FROM read_json_auto('public_v2.ndjson')
    LIMIT 1000
""").df()

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   referrer   1000 non-null   str
#  1   request    1000 non-null   str
#  2   method     998 non-null    str
#  3   resource   998 non-null    str
#  4   bytes      1000 non-null   str
#  5   response   1000 non-null   str
#  6   ip         1000 non-null   str
#  7   useragent  1000 non-null   str
#  8   timestamp  1000 non-null   str
#  9   log_id     1000 non-null   str
# dtypes: str(10)
# memory usage: 78.3 KB

# %%
attacks = [
    {
        "referrer": "http://search.lib.auth.gr/Search/<script>alert('XSS')</script>",
        "request": "search.lib.auth.gr:80 185.22.12.44 - - [01/Mar/2018:00:00:15 +0200] GET /Search?q=<script>alert('XSS')</script> HTTP/1.1 400 1200 http://search.lib.auth.gr/Search/<script>alert('XSS')</script> Mozilla/5.0",
        "method": "GET",
        "resource": "/Search?q=<script>alert('XSS')</script>",
        "bytes": "1200",
        "response": "400",
        "ip": "185.22.12.44",
        "useragent": "Mozilla/5.0",
        "timestamp": "2018-02-28T22:00:15.000Z",
        "log_id": "attack_xss"
    },
    {
        "referrer": "http://evil.com",
        "request": "search.lib.auth.gr:80 45.77.88.12 - - [01/Mar/2018:00:00:20 +0200] GET /login?user=admin' OR 1=1-- HTTP/1.1 500 800 http://evil.com Mozilla/5.0",
        "method": "GET",
        "resource": "/login?user=admin' OR 1=1--",
        "bytes": "800",
        "response": "500",
        "ip": "45.77.88.12",
        "useragent": "Mozilla/5.0",
        "timestamp": "2018-02-28T22:00:20.000Z",
        "log_id": "attack_sql"
    },
    {
        "referrer": "-",
        "request": "search.lib.auth.gr:80 91.200.12.77 - - [01/Mar/2018:00:00:25 +0200] GET /../../../../etc/passwd HTTP/1.1 403 300 - curl/7.58.0",
        "method": "GET",
        "resource": "/../../../../etc/passwd",
        "bytes": "300",
        "response": "403",
        "ip": "91.200.12.77",
        "useragent": "curl/7.58.0",
        "timestamp": "2018-02-28T22:00:25.000Z",
        "log_id": "attack_traversal"
    },
    {
        "referrer": "-",
        "request": "search.lib.auth.gr:80 203.0.113.45 - - [01/Mar/2018:00:00:30 +0200] GET /wp-admin/install.php HTTP/1.1 404 250 - sqlmap/1.7",
        "method": "GET",
        "resource": "/wp-admin/install.php",
        "bytes": "250",
        "response": "404",
        "ip": "203.0.113.45",
        "useragent": "sqlmap/1.7",
        "timestamp": "2018-02-28T22:00:30.000Z",
        "log_id": "attack_scanner"
    }
]

df = pd.concat([df, pd.DataFrame(attacks)], ignore_index=True)

# %%
#timestamp in formato coerente

df["timestamp"] = pd.to_datetime(df["timestamp"])

# %%
#lughezza della resource richiesta

df["resource_len"] = df["resource"].str.len()

# %%
#da valutare se devo fare un primo controllo anche io sui quartili
from detect import has_suspicious_request_len

df = has_suspicious_request_len(df)

# %%
#troppi special characters
df["special_chars"] = df["request"].str.count(r"[<>\'\"%;(){}]*+@")
df["special_chars"].value_counts()
# Out:
# special_chars
# 0    1001
# 1       1
# Name: count, dtype: int64

# %%
#directory traversale
df["has_traversal"] = df["request"].str.contains(r"\.\./", regex=True, na=False).astype(int)
df["has_traversal"].value_counts()
# Out:
# has_traversal
# 0    1001
# 1       1
# Name: count, dtype: int64

# %%
# sql injection

df["has_sql_keywords"] = df["request"].str.contains(
    r"union|select|insert|drop|or 1=1|--|admin",
    case=False,
    na=False
).astype(int)

df["has_sql_keywords"].value_counts()
# Out:
# has_sql_keywords
# 0    1000
# 1       2
# Name: count, dtype: int64

# %%
#script injection
df["has_script_tag"] = df["request"].str.contains(
    r"<script>",
    case=False,
    na=False
).astype(int)
df["has_script_tag"].value_counts()
# Out:
# has_script_tag
# 0    1001
# 1       1
# Name: count, dtype: int64

# %%
#possibile scanner da parte di bot ostili
df["scanner_agent"] = df["useragent"].str.contains(
    r"sqlmap|nikto|curl|nmap|dirbuster",
    case=False,
    na=False
).astype(int)
df["useragent"].value_counts()
# Out:
# useragent
# Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/64.0.3282.186 Safari/537.36                              367
# Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/64.0.3282.167 Safari/537.36                               126
# Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/64.0.3282.186 Safari/537.36                               118
# Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:58.0) Gecko/20100101 Firefox/58.0                                                                    81
# BUbiNG (+http://law.di.unimi.it/BUbiNG.html)                                                                                                      79
# ICC-Crawler/2.0 (Mozilla-compatible; ; http://ucri.nict.go.jp/en/icccrawler.html)                                                                 70
# Mozilla/5.0 (Windows NT 10.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.84 Safari/537.36                                            55
# Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/64.0.3282.186 Safari/537.36                                50
# Mozilla/5.0 (Linux; Android 7.0; WAS-LX1 Build/HUAWEIWAS-LX1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.98 Mobile Safari/537.36     15
# Mozilla/5.0 (Linux; U; Android 4.1.2; el-gr; LG-E455 Build/JZO54K) AppleWebKit/534.30 (KHTML, like Gecko) Version/4.0 Mobile Safari/534.30        13
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/604.5.6 (KHTML, like Gecko) Version/11.0.3 Safari/604.5.6                             11
# Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)                                                                           6
# com.apple.Safari.SearchHelper/11604.5.6.1.1 CFNetwork/760.8 Darwin/15.6.0 (x86_64)                                                                 2
# Mozilla/5.0                                                                                                                                        2
# Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36                                1
# Mozilla/5.0 (compatible; bingbot/2.0; +http://www.bing.com/bingbot.htm)                                                                            1
# Apple-PubSub/65.28                                                                                                                                 1
# Mozilla/5.0 (compatible; Baiduspider/2.0; +http://www.baidu.com/search/spider.html)                                                                1
# Mozilla/5.0 (compatible; DotBot/1.1; http://www.opensiteexplorer.org/dotbot, help@moz.com)                                                         1
# curl/7.58.0                                                                                                                                        1
# sqlmap/1.7                                                                                                                                         1
# Name: count, dtype: int64

# %%
# status code di errore
df["is_error"] = (df["response"].astype(int) >= 400).astype(int)

df['is_error'].value_counts()
# Out:
# is_error
# 0    997
# 1      5
# Name: count, dtype: int64

# %%
# numero di query eccessivo
df["num_params"] = df["resource"].str.count("=")
df["num_params"].value_counts()
# Out:
# num_params
# 0    871
# 1    126
# 6      2
# 3      1
# 4      1
# 2      1
# Name: count, dtype: int64

# %%
# numero di richieste per IP
df["requests_per_ip"] = df.groupby("ip")["ip"].transform("count")

# %%
from detect import entropy

df["request_entropy"] = df["request"].apply(lambda x: entropy(str(x)))

# %%
df['bytes_num'] = pd.to_numeric(df['bytes'], errors='coerce').fillna(0)
resource_avg_bytes = df.groupby('resource')['bytes_num'].transform('mean')

df['bytes_ratio'] = df['bytes_num'] / (resource_avg_bytes + 1)
df['bytes_ratio'].value_counts()
# Out:
# bytes_ratio
# 0.998525    230
# 0.998527     70
# 0.997963     45
# 0.997967     13
# 0.999814     12
#            ...
# 0.999190      1
# 0.999167      1
# 0.998752      1
# 0.996678      1
# 0.996016      1
# Name: count, Length: 427, dtype: int64

# %%
bot_keywords = [
        'bot', 'crawler', 'spider', 'slurp', 'bingpreview', 'thumbshot',
        'bubing', 'dotbot', 'icc-crawler', 'googlebot', 'yandex', 'baidu'
    ]
bot_pattern = '|'.join(bot_keywords)
df["is_known_bot"] = df["useragent"].str.contains(bot_pattern, case = False, na = False).astype(int)

# %%
df = df[df["is_known_bot"]==0]

# %% [markdown]
# DA QUI IN POI ABBIAMO L'ALGORITMO DI ISOLATION FOREST
# 1. L'algoritmo non accetta stringhe o date. Dobbiamo isolare solo le colonne numeriche.

# %%
features_numeriche = [
    'resource_len', 'num_params', 'requests_per_ip', 'request_entropy', 'bytes_num',
    'bytes_ratio'
]

features_boolean = [
    'has_suspicious_request_len', 'special_chars',
    'has_traversal', 'has_sql_keywords', 'has_script_tag',
    'scanner_agent', 'is_error',
]

# %%
from sklearn.ensemble import IsolationForest

# Definiamo le colonne che l'algoritmo deve "studiare"
features = [
    'resource_len', 'has_suspicious_request_len', 'special_chars',
    'has_traversal', 'has_sql_keywords', 'has_script_tag',
    'scanner_agent', 'is_error', 'num_params',
    'requests_per_ip', 'request_entropy', 'bytes_num',
    'bytes_ratio','is_known_bot'
]

X = df[features]
X
# Out:
#       resource_len  has_suspicious_request_len  special_chars  has_traversal  \
# 2               72                           0              0              0
# 3               70                           0              0              0
# 4               80                           0              0              0
# 5               70                           0              0              0
# 7               70                           0              0              0
# ...            ...                         ...            ...            ...
# 999             80                           0              0              0
# 1000            39                           1              0              0
# 1001            27                           1              0              0
# 1002            23                           1              0              1
# 1003            21                           1              0              0
#
#       has_sql_keywords  has_script_tag  scanner_agent  is_error  num_params  \
# 2                    0               0              0         0           0
# 3                    0               0              0         0           0
# 4                    0               0              0         0           0
# 5                    0               0              0         0           0
# 7                    0               0              0         0           0
# ...                ...             ...            ...       ...         ...
# 999                  0               0              0         0           0
# 1000                 0               1              0         1           1
# 1001                 1               0              0         1           2
# 1002                 0               0              1         1           0
# 1003                 1               0              1         1           0
#
#       requests_per_ip  request_entropy  bytes_num  bytes_ratio  is_known_bot
# 2                  15         5.075418       8952     0.999888             0
# 3                  15         5.103453        490     0.997963             0
# 4                  15         5.148262        677     0.998525             0
# 5                  28         5.261221       1227     0.999186             0
# 7                  28         5.260815        991     0.998992             0
# ...               ...              ...        ...          ...           ...
# 999                69         5.302785        677     0.998525             0
# 1000                1         5.028478       1200     0.999167             0
# 1001                1         4.966076        800     0.998752             0
# 1002                1         4.569546        300     0.996678             0
# 1003                1         4.795299        250     0.996016             0
#
# [844 rows x 14 columns]

# %% [markdown]
# 2. Configurazione e Addestramento
# L'Isolation Forest funziona creando alberi decisionali casuali: le anomalie vengono "isolate" più velocemente.

# %%
# contamination è la % stimata di attacchi nel dataset (es. 0.1% = 0.001)
model = IsolationForest(n_estimators=100, contamination=0.01, random_state=42)

# Addestramento
df['anomaly_score'] = model.fit_predict(X)

model
# Risultato: -1 significa Anomalia, 1 significa Traffico Normale
# Out:
# IsolationForest(contamination=0.01, random_state=42)

# %% [markdown]
# 3. Interpretazione dei risultati

# %%
# Punteggio grezzo: valori negativi = più anomalo
df['scores'] = model.decision_function(X)

# per vedere se gli attacchi sono stati classificati come tali
df[df['log_id'].str.contains('attack')][['log_id', 'anomaly_score', 'scores']]
# Out:
#                 log_id  anomaly_score    scores
# 1000        attack_xss             -1 -0.072516
# 1001        attack_sql             -1 -0.128616
# 1002  attack_traversal             -1 -0.128129
# 1003    attack_scanner             -1 -0.147385

# %% [markdown]
# 4. Verifica dei Falsi Positivi

# %%
# Mostra le 10 richieste più sospette del dataset
top_anomalies = df.sort_values(by='scores').head(10)
a = top_anomalies[['request', 'useragent','scores', 'log_id', 'is_known_bot']]
a
# Gli attacchi che ho inserito io non sono in questa top... sono bot di google
# Out:
#                                                 request  \
# 1003  search.lib.auth.gr:80 203.0.113.45 - - [01/Mar...
# 1001  search.lib.auth.gr:80 45.77.88.12 - - [01/Mar/...
# 1002  search.lib.auth.gr:80 91.200.12.77 - - [01/Mar...
# 826   search.lib.auth.gr:80 176.92.34367 - - [01/Mar...
# 1000  search.lib.auth.gr:80 185.22.12.44 - - [01/Mar...
# 918   search.lib.auth.gr:80 176.92.34367 - - [01/Mar...
# 629   search.lib.auth.gr:80 155.207.36594 - - [01/Ma...
# 327   search.lib.auth.gr:80 85.74.35922 - - [01/Mar/...
# 59    search.lib.auth.gr:80 141.237.44390 - - [01/Ma...
# 871   search.lib.auth.gr:80 94.68.51815 - - [01/Mar/...
#
#                                               useragent    scores  \
# 1003                                         sqlmap/1.7 -0.147385
# 1001                                        Mozilla/5.0 -0.128616
# 1002                                        curl/7.58.0 -0.128129
# 826   Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl... -0.094709
# 1000                                        Mozilla/5.0 -0.072516
# 918   Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl... -0.040505
# 629   Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl... -0.028641
# 327   Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:5... -0.019385
# 59    Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple... -0.001814
# 871   Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...  0.002404
#
#                     log_id  is_known_bot
# 1003        attack_scanner             0
# 1001            attack_sql             0
# 1002      attack_traversal             0
# 826   xbRfsmoBCue8G08E0FlG             0
# 1000            attack_xss             0
# 918   WrRfsmoBCue8G08Ez1ki             0
# 629   hLRfsmoBCue8G08E0VpD             0
# 327   trRfsmoBCue8G08E01sU             0
# 59    s7RfsmoBCue8G08E1FxY             0
# 871   jrRfsmoBCue8G08E0FlG             0

# %% [markdown]
# Dato che ho inserito degli attacchi manualmente (attack_xss, attack_sql, ecc.), posso calcolare una Matrice di Confusione semplificata per dimostrare quanto l'algoritmo è efficace nel trovare "l'ago nel pagliaio" che ho nascosto io.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report



df['is_attack_real'] = df['log_id'].str.contains('attack').astype(int)

df['is_attack_predicted'] = df['anomaly_score'].apply(lambda x: 1 if x == -1 else 0)

cm = confusion_matrix(df['is_attack_real'], df['is_attack_predicted'])

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Normale', 'Attacco'],
            yticklabels=['Normale', 'Attacco'])
plt.xlabel('Predizione Modello')
plt.ylabel('Realtà (Ground Truth)')
plt.title('Matrice di Confusione')
plt.show()

# TODO -> Isolare i bot di google che creano parecchio rumore di fondo

# %%
print(classification_report(df['is_attack_real'], df['is_attack_predicted']))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00       840
#            1       0.44      1.00      0.62         4
#
#     accuracy                           0.99       844
#    macro avg       0.72      1.00      0.81       844
# weighted avg       1.00      0.99      1.00       844

# %%
test_attacks = df[df['log_id'].str.contains('attack')]
test_attacks[['log_id', 'anomaly_score', 'scores']]
# Out:
#                 log_id  anomaly_score    scores
# 1000        attack_xss             -1 -0.072516
# 1001        attack_sql             -1 -0.128616
# 1002  attack_traversal             -1 -0.128129
# 1003    attack_scanner             -1 -0.147385
